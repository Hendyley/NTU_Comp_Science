# %%
import http.client
import requests
from urllib.request import Request, urlopen
import json

import pandas as pd

from pathlib import Path

# %%
url = "https://google-news1.p.rapidapi.com/search"

querystring = {"q":"Apple","country":"US","lang":"en","before":"2019-09-01","after":"2019-08-01"}

headers = {
	"X-RapidAPI-Host": "google-news1.p.rapidapi.com",
	"X-RapidAPI-Key": "60ba6c2c8emsha8a15e53ec84acdp14aeb3jsncd684f9e15bd"
}

response = requests.request("GET", url, headers=headers, params=querystring)
x = response.text

data = json.loads(x)
News_O = pd.json_normalize(data["articles"])
#News_O.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7764/2491367106.py in <module>
#      12
#      13 data = json.loads(x)
# ---> 14 News_O = pd.json_normalize(data["articles"])
#      15 #News_O.head()
#
# KeyError: 'articles'

# %%
x
# Out:
# '{"message":"You have exceeded the DAILY quota for Requests on your current plan, BASIC. Upgrade your plan at https:\\/\\/rapidapi.com\\/ubillarnet\\/api\\/google-news1"}'

# %%
pd.set_option('display.max_rows', None)
News_O.to_clipboard(sep=',', index=False)
News_O
# Out:
#                                                    id  \
# 0                                      52780358612631
# 1                                      52780367513443
# 2   CBMiX2h0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 3   CBMie2h0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 4   CBMiS2h0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 5   CBMiXGh0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 6   CAIiEDgQ7Kp6eHfzPz6ML7qdVmwqGQgEKhAIACoHCAow2N...
# 7   CBMiW2h0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 8   CAIiEPLC-w6HYMINKFJ-80g9sugqFggEKg4IACoGCAow3O...
# 9   CBMicWh0dHBzOi8vd3d3LmFwcGxlLmNvbS9uZXdzcm9vbS...
# 10  CAIiEJItKCNXpwDje1Rf44u8398qFwgEKg4IACoGCAow3O...
# 11  CBMiR2h0dHBzOi8vd3d3LnBjbWFnLmNvbS9ob3ctdG8vaG...
# 12  CAIiEAi7pQVsrLDBJC9P7mkfHB8qFwgEKg8IACoHCAow8d...
# 13  CAIiEN6L6CfLIgF2yzvNsf6ctmwqGAgEKg8IACoHCAowi4...
# 14  CBMiOGh0dHBzOi8vd3d3Lm1hY3J1bW9ycy5jb20vaG93LX...
# 15  CAIiEP8e2x_9cJhySfDuM0cRgl8qFAgEKg0IACoGCAowt6...
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
count_vectorizer = CountVectorizer()
count_vectorizer.fit_transform(x_df)
freq_term_matrix = count_vectorizer.transform(x_df)

tfidf = TfidfTransformer(norm = "l2")
tfidf.fit(freq_term_matrix)
tf_idf_matrix = tfidf.fit_transform(freq_term_matrix)

print(tf_idf_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57180/227786570.py in <module>
#       1 count_vectorizer = CountVectorizer()
# ----> 2 count_vectorizer.fit_transform(x_df)
#       3 freq_term_matrix = count_vectorizer.transform(x_df)
#       4
#       5 tfidf = TfidfTransformer(norm = "l2")
#
# NameError: name 'x_df' is not defined

# %% [markdown]
# ### Another Format

# %%
#url = "https://google-news1.p.rapidapi.com/search"
url = "https://google-news.p.rapidapi.com/v1/search"

querystring = {"q":"Apple","country":"US","from":"2019-08-01","to":"2019-09-01","lang":"en"}

headers = {
	"X-RapidAPI-Host": "google-news.p.rapidapi.com",
	"X-RapidAPI-Key": "66f1390e1bmsh309c8de38c9e7fep11a041jsn94a2868012bf"
}

response = requests.request("GET", url, headers=headers, params=querystring)
x = response.text

data = json.loads(x)
News_O = pd.json_normalize(data["articles"])
#News_O.head()
