# %%
import http.client
import requests
from urllib.request import Request, urlopen
import json

import pandas as pd

from pathlib import Path

# %%
url = "https://google-news1.p.rapidapi.com/search"

querystring = {"q":"Apple","country":"US","lang":"en","before":"2020-08-01","after":"2020-06-01"}

headers = {
	"X-RapidAPI-Host": "google-news1.p.rapidapi.com",
	"X-RapidAPI-Key": "60ba6c2c8emsha8a15e53ec84acdp14aeb3jsncd684f9e15bd"
}

response = requests.request("GET", url, headers=headers, params=querystring)
x = response.text

data = json.loads(x)
News_O = pd.json_normalize(data["articles"])
#News_O.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2300/1052940417.py in <module>
#      12
#      13 data = json.loads(x)
# ---> 14 News_O = pd.json_normalize(data["articles"])
#      15 #News_O.head()
#
# KeyError: 'articles'

# %%
x
# Out:
# '{"message":"Endpoint\\/search does not exist"}'

# %%
url = "https://google-news1.p.rapidapi.com/search"

querystring = {"q":"Apple","country":"US","lang":"en","before":"2021-09-09","after":"2021-08-01"}

headers = {
	"X-RapidAPI-Host": "google-news1.p.rapidapi.com",
	"X-RapidAPI-Key": "a3afdd4bb8msh72cc54d73330c50p19b013jsnef23e052858d"
}

response = requests.request("GET", url, headers=headers, params=querystring)
x = response.text

data = json.loads(x)
News_O = pd.json_normalize(data["articles"])
#News_O.head()

# %%
pd.set_option('display.max_rows', None)
News_O.to_clipboard(sep=',', index=False)
News_O
# Out:
#                published_date  \
# 0   2021-08-26T07:00:00+00:00
# 1   2021-09-01T07:00:00+00:00
# 2   2021-09-01T07:00:00+00:00
# 3   2021-09-01T07:00:00+00:00
# 4   2021-08-15T07:00:00+00:00
# 5   2021-08-17T07:00:00+00:00
# 6   2021-08-05T07:00:00+00:00
# 7   2021-08-25T07:00:00+00:00
# 8   2021-08-03T07:00:00+00:00
# 9   2021-09-01T07:00:00+00:00
# 10  2021-08-30T07:00:00+00:00
# 11  2021-08-26T07:00:00+00:00
# 12  2021-08-24T07:00:00+00:00
# 13  2021-08-10T07:00:00+00:00
# 14  2021-08-30T07:00:00+00:00
# 15  2021-08-19T07:00:00+00:00
# 16  2021-08-01T07:00:00+00:00
# 17  2021-09-03T07:00:00+00:00
# 18  2021-08-29T07:00:00+00:00
# 19  2021-08-24T07:00:00+00:00
# 20  2021-09-08T07:00:00+00:00
# 21  2021-08-29T07:00:00+00:00
# 22  2021-08-26T07:00:00+00:00
# 23  2021-09-03T07:00:00+00:00
# 24  2021-08-17T07:00:00+00:00
# 25  2021-08-19T20:43:23+00:00
# 26  2021-08-08T07:00:00+00:00
# 27  2021-08-19T07:00:00+00:00
# 28  2021-09-08T07:00:00+00:00
# 29  2021-09-02T07:00:00+00:00
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
count_vectorizer = CountVectorizer()
count_vectorizer.fit_transform(x_df)
freq_term_matrix = count_vectorizer.transform(x_df)

tfidf = TfidfTransformer(norm = "l2")
tfidf.fit(freq_term_matrix)
tf_idf_matrix = tfidf.fit_transform(freq_term_matrix)

print(tf_idf_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_57180/227786570.py in <module>
#       1 count_vectorizer = CountVectorizer()
# ----> 2 count_vectorizer.fit_transform(x_df)
#       3 freq_term_matrix = count_vectorizer.transform(x_df)
#       4
#       5 tfidf = TfidfTransformer(norm = "l2")
#
# NameError: name 'x_df' is not defined

# %% [markdown]
# ### Another Format with time

# %%
url = "https://google-news1.p.rapidapi.com/search"

querystring = {"q":"Apple","country":"US","lang":"en","before":"2020-08-01","after":"2020-06-01"}

headers = {
	"X-RapidAPI-Host": "google-news1.p.rapidapi.com",
	"X-RapidAPI-Key": "a3afdd4bb8msh72cc54d73330c50p19b013jsnef23e052858d"
}

response = requests.request("GET", url, headers=headers, params=querystring)
x = response.text

data = json.loads(x)
News_O = pd.json_normalize(data["articles"])
#News_O.head()

# %%
x
# Out:
# '{"statusCode":404,"error":"Not Found","message":"Not Found"}'
